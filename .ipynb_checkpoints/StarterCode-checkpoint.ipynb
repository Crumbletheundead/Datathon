# %%
import pandas as pd
import numpy as np
import json
import os

# %%
csvs = os.listdir(path = 'data')
files = []
for file in csvs:
    fp = os.path.join('data', file)
    files.append(fp)

# %%
traffic = pd.read_csv(files[0])
col_dict = pd.read_csv(files[1])
collisions = pd.read_csv(files[2])
traffic_dict = pd.read_csv(files[3])

# %%
traffic.head()
# Out:
#            id street_name             limits all_count northbound_count  \
# 0  01AV018207       01 AV      A ST - ASH ST                      18010
# 1  01AV015210       01 AV      A ST - ASH ST                      20060
# 2  01AV018213       01 AV      A ST - ASH ST                      19597
# 3  01AV088812       01 AV  ASH ST - BEECH ST                       2298
# 4  01AV068711       01 AV        B ST - A ST                      15625
#
#    southbound_count  eastbound_count  westbound_count  total_count  file_no  \
# 0               NaN              NaN              NaN        18010  0182-07
# 1               NaN              NaN              NaN        20060  0152-10
# 2               NaN              NaN              NaN        19597  0182-13
# 3               NaN              NaN              NaN         2298  0888-12
# 4               NaN              NaN              NaN        15625  0687-11
#
#             count_date
# 0  2007-03-13 00:00:00
# 1  2010-03-18 00:00:00
# ...

# %%
traffic_dict.head()
# Out:
#       # Datathon
# 0  2019 Datathon

# %%
collisions.head()
# Out:
#   report_id            date_time  police_beat  street_no street_dir  \
# 0    170166  2017-01-01 00:01:00          124       8300
# 1    170218  2017-01-01 00:01:00          325       8100
# 2    170101  2017-01-01 00:01:00          322       6400
# 3    170082  2017-01-01 00:01:00          935       5500
# 4    170097  2017-01-01 01:00:00          521       1000
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 0  CAM DEL ORO
# 1  ROYAL GORGE       DRIVE
# 2     CRAWFORD      STREET
# 3      VALERIO       TRAIL
# 4         11TH      AVENUE
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
# 1             22107             VC
# 2          MISC-HAZ             VC
# 3          MISC-HAZ             VC
# 4             22107             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# ...

# %%
col_dict.head()
# Out:
#             Field                                        Description  \
# 0  activityNumber                            Collision report number
# 1    activityDate                             Date/time of collision
# 2            beat                              San Diego Police beat
# 3        StreetNo  Street number of collision location, abstracte...
# 4       StreetDir                    Direction of street in location
#
#                           Values  Unnamed: 3
# 0                            NaN         NaN
# 1  Date / time in 24 hour format         NaN
# 2                  see code list         NaN
# 3                            NaN         NaN
# 4                            NaN         NaN
